# %% [markdown]
# ### Training

# %% [markdown]
# #### SwinUNETR Plus

# %%
# !python run.py \                                                 
#     --dataset brats2023 \
#     --seed 133 \
#     --epochs 125 \                                                                                    
#     --batch_size 1 \
#     --accumulate_grad_batches 4 \                                                                    
#     --num_workers 3 \                                                                                
#     --img_size 96 \
#     --feature_size 48 \
#     --roi_size 96 96 96 \
#     --sw_batch_size 2 \
#     --overlap 0.7 \
#     --learning_rate 5e-4 \
#     --loss_type dicece \
#     --warmup_epochs 10 \
#     --limit_val_batches 30 \
#     --val_interval 3 \
#     --threshold 0.5 \
#     --use_class_weights \
#     --class_weights 1.3 1.0 1.5 \
#     --optimizer_type adamw8bit \
#     --precision 16-mixed \
#     --patch_norm \
#     --use_modality_attention \
#     --use_multi_scale_attention \
#     --multi_scale_window_sizes 7 5 3 \
#     --use_hierarchical_skip \
#     --use_v2 \
#     --gradient_clip_val 1.0 \
#     --gradient_clip_algorithm norm \
#     --use_local

# %% [markdown]
# ### SwinMamba

# %%
# !python run.py \
    --dataset brats2023 \
    --seed 256 \
    --epochs 230 \
    --batch_size 2 \
    --accumulate_grad_batches 8 \
    --num_workers 3 \
    --img_size 96 \
    --feature_size 48 \
    --roi_size 96 96 96 \
    --sw_batch_size 2 \
    --overlap 0.8 \
    --learning_rate 5e-4 \
    --loss_type dicefocal \
    --lambda_dice 0.7 \
    --lambda_focal 1.3 \
    --focal_alpha 0.75 \
    --warmup_epochs 5 \
    --limit_val_batches 30 \
    --val_interval 1 \
    --threshold 0.6 \
    --use_class_weights \
    --class_weights 1.3 1.0 1.5 \
    --optimizer_type adamw8bit \
    --precision bf16-mixed \
    --patch_norm \
    --use_v2 \
    --use_mamba \
    --mamba_type swinmamba \
    --gradient_clip_val 1.0 \
    --gradient_clip_algorithm norm \
    --d_state 16 \
    --d_conv 3 \
    --expand 1 \
    --data_dir "/mnt/Data 2/BRATS-datasets/BRATS2023-training"
# Out:
# Mamba architectures available:
#   - SegMamba: Pure state-space model
#   - SwinMamba: SwinUNETR encoder + multi-directional Mamba
#   - MambaUNETR: Mamba encoder + SwinUNETR decoder
#   - VITMamba: Axial-ViT (stages 0-1) + Mamba (stages 2-3)
#   - MambaFormer: NNFormer-Swin (stages 0-1) + Mamba (stages 2-3)
#   - MambaSwinV2: Mamba (stages 0-1) + Swin (stages 2-3)
# Processing dataset from: /mnt/Data 2/BRATS-datasets/BRATS2023-training
#   Added: BraTS-GLI-00000-000
#   Added: BraTS-GLI-00002-000
#   Added: BraTS-GLI-00003-000
#   Added: BraTS-GLI-00005-000
#   Added: BraTS-GLI-00006-000
#   Added: BraTS-GLI-00008-000
#   Added: BraTS-GLI-00008-001
#   Added: BraTS-GLI-00009-000
#   Added: BraTS-GLI-00009-001
#   Added: BraTS-GLI-00011-000
#
# 1251 valid cases, 0 skipped
# Wrote dataset.json -> dataset/dataset.json
# Processed dataset saved to: dataset
#
# ===  ADAPTIVE SWINUNETR CONFIGURATION ===
#  Batch size: 2
#  Gradient accumulation: 8 (effective batch: 16)
#  Image size: 96
#  Learning rate: 0.0005
#  Warmup epochs: 5
#  Loss type: dicefocal
#  SW batch size: 2
#  Total epochs: 230
#  Dataset: brats2023
#  Use class weights: True
#  Use modality attention: False
#  Class weights: (1.3, 1.0, 1.5)
#  Tversky : 0.5, : 0.5
#  Focal : 2.0, : 0.75
#  GDL weight type: square, : 1.0
#  Hausdorff : 2.0
#  Loss weights - Dice: 0.7, Focal: 1.3, Tversky: 1.0, Hausdorff: 1.0
#  Threshold: 0.6
#  ROI size: [96, 96, 96]
#  Early stop patience: None
#  Limit val batches: 30
#  Val interval: 1
#  Adaptive scheduling: False
#  Warm restarts: False
#  ReduceLROnPlateau: False
#  Scheduler: Warmup + Cosine Annealing
#
# ===  SWINUNETR PLUS ENHANCEMENTS ===
#  Multi-scale attention: False
#  Adaptive window: False
#  Cross-layer fusion: False
#  Hierarchical skip: False
#  Enhanced V2 blocks: False
#  Multi-scale window sizes: [7, 5, 3]
#  Use V2 blocks: True
#  Patch normalization: True
#  Optimizer: adamw8bit
#  Precision: bf16-mixed
#  Use Mamba: True
#  Mamba Type: swinmamba
#  Mamba d_state: 16
#  Mamba d_conv: 3
#  Mamba expand: 1
#  Window size: [4, 4, 4]
#  Compile model: False
#  Input directory: dataset
#  Output directory: /home/mkultra/Documents/498R/PublicRepo/SwinSSM
# ========================================
#
# Step 1: Setting up MONAI transforms...
# Step 2: Creating dataloaders...
# Found 1251 samples in dataset
# Dataset split: 750 train, 250 val, 251 test
# Step 3: Setting up training...
#  Random seed set to: 256
# Using SwinMamba - SwinUNETR encoder + multi-directional Mamba
# Using bfloat16 Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# `Trainer(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
#
# Model Parameter Count: 66.32M
# Model Size: 253.00 MB
#
# Step 4: Starting training...
# You are using a CUDA device ('NVIDIA GeForce RTX 3060') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# wandb: Currently logged in as: imrozeshan (imrozrahim-edu-north-south-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ creating run (0.5s)
# wandb: ⣻ creating run (0.5s)
# wandb: ⣽ creating run (0.5s)
# wandb: ⣾ creating run (0.5s)
# wandb: ⣷ creating run (1.0s)
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in ./wandb/run-20260228_220716-85a5lwdg
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run dicefocal-e230-lr5e-04-weighted
# wandb: ⭐️ View project at https://wandb.ai/imrozrahim-edu-north-south-university/brain-tumor-segmentation
# wandb: 🚀 View run at https://wandb.ai/imrozrahim-edu-north-south-university/brain-tumor-segmentation/runs/85a5lwdg
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                        | Type                     | Params | Mode
# ---------------------------------------------------------------------------------
# 0 | model                       | SwinMamba                | 66.3 M | train
# 1 | dice_loss                   | DiceLoss                 | 0      | train
# 2 | dicece_loss                 | DiceCELoss               | 0      | train
# 3 | dicefocal_loss              | DiceFocalLoss            | 0      | train
# 4 | generalized_dice_loss       | GeneralizedDiceLoss      | 0      | train
# 5 | generalized_dice_focal_loss | GeneralizedDiceFocalLoss | 0      | train
# 6 | focal_loss                  | FocalLoss                | 0      | train
# 7 | tversky_loss                | TverskyLoss              | 0      | train
# 8 | hausdorff_loss              | HausdorffDTLoss          | 0      | train
# 9 | s3f_loss                    | S3FLoss                  | 0      | train
# ---------------------------------------------------------------------------------
# 66.3 M    Trainable params
# 0         Non-trainable params
# 66.3 M    Total params
# 265.287   Total estimated model params size (MB)
# 369       Modules in train mode
# 0         Modules in eval mode
# Epoch 0:   0%|                                          | 0/375 [00:00<?, ?it/s]

# %% [markdown]
# ### Validation

# %% [markdown]
# ### SwinMambaV2

# %%
# !python -u src/utils/validation.py \
    --dataset brats2021 \
    --feature_size 48 \
    --use_mamba \
    --mamba_type swinmamba \
    --roi_size 96 96 96 \
    --batch_size 1 \
    --sw_batch_size 2 \
    --num_workers 3 \
    --overlap 0.8 \
    --threshold 0.5 \
    --use_modality_attention \
    --wt_threshold 250 \
    --tc_threshold 150 \
    --et_threshold 100 \
    --d_state 8 \
    --d_conv 3 \
    --expand 1 \
    --checkpoint_path "checkpoints/SwinMamba-2021/swinunetr-epoch=04-val_mean_dice=0.8893.ckpt" \
    --log_to_wandb \
    --wandb_project "validation" \
    --precision bf16 \
    --outlier_threshold 0.4 \
    --data_dir "dataset/dataset.json"

# %% [markdown]
# ### MambaUNETR

# %%
# !python -u src/utils/validation.py \
    --dataset brats2021 \
    --feature_size 48 \
    --use_mamba \
    --mamba_type segmamba \
    --roi_size 96 96 96 \
    --batch_size 1 \
    --sw_batch_size 2 \
    --num_workers 3 \
    --overlap 0.8 \
    --threshold 0.5 \
    --use_modality_attention \
    --wt_threshold 250 \
    --tc_threshold 150 \
    --et_threshold 100 \
    --d_state 8 \
    --d_conv 3 \
    --expand 1 \
    --checkpoint_path "checkpoints/MambaUNETR-2021/best.ckpt" \
    --log_to_wandb \
    --wandb_project "validation" \
    --precision bf16 \
    --outlier_threshold 0.4 \
    --data_dir "dataset/dataset.json"

# %% [markdown]
# ### SwinUNETR Plus

# %%
# !python -u src/utils/validation.py \
    --dataset brats2021 \
    --feature_size 48 \
    --roi_size 96 96 96 \
    --batch_size 1 \
    --sw_batch_size 2 \
    --num_workers 3 \
    --overlap 0.8 \
    --threshold 0.5 \
    --use_modality_attention \
    --use_multi_scale_attention \
    --use_hierarchical_skip \
    --use_v2 \
    --use_enhanced_v2_blocks \
    --patch_norm \
    --wt_threshold 250 \
    --tc_threshold 150 \
    --et_threshold 100 \
    --checkpoint_path "checkpoints/SwinUNETRPlus-2021/best.ckpt" \
    --log_to_wandb \
    --wandb_project "validation" \
    --precision bf16 \
    --outlier_threshold 0.4 \
    --data_dir "dataset/dataset.json"

# %% [markdown]
# ## Ensemble

# %%
# !python src/utils/ensemble.py \
    --ensemble_checkpoints "checkpoints/MambaUNETR-2021/best.ckpt" "checkpoints/SwinUNETRPlus-2021/best.ckpt" "checkpoints/SwinMambaV2-2021/swinunetr-epoch=04-val_mean_dice=0.8893.ckpt" \
    --model_types segmamba swinunetr swinmamba \
    --mamba_types segmamba swinmamba \
    --data_dir dataset/dataset.json \
    --dataset brats2021 \
    --overlap 0.75 \
    --batch_size 1 \
    --sw_batch_size 2 \
    --roi_size 96 96 96 \
    --threshold 0.5 \
    --use_v2 \
    --use_modality_attention \
    --use_multi_scale_attention \
    --use_hierarchical_skip \
    --use_enhanced_v2_blocks \
    --patch_norm \
    --d_state 8 \
    --d_conv 3 \
    --expand 1 \
    --wt_threshold 250 \
    --tc_threshold 150 \
    --et_threshold 100 \
    --num_workers 3 \
    --log_to_wandb \
    --wandb_project "ensemble_validation_brats2021" \
    --outlier_threshold 0.5 \
    --precision bf16
